# %% [markdown]
# <a href="https://colab.research.google.com/github/SANGRAMLEMBE/Computer_Vision_from_Scratch/blob/main/simple_convolution_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import convolve2d
from skimage import data, color

# Load grayscale image
image = color.rgb2gray(data.coffee())

# Define a simple edge detection Filter

filter = np.array([[-1,-1,-1],
                   [0,0,0],
                   [1,1,1]])
# Apply Convolution

convolved = convolve2d(image, filter, mode = 'same', boundary = 'symm')


# Show result

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image, cmap = 'gray')
plt.subplot(1,2,2)
plt.title("After Convolution")
plt.imshow(convolved, cmap = 'gray')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import convolve2d
from skimage import data, color

# Load grayscale image
image = color.rgb2gray(data.coffee())

# Define a simple edge detection Filter

filter = np.array([[-1,0,1],
                   [-1,0,1],
                   [-1,0,1]])
# Apply Convolution

convolved = convolve2d(image, filter, mode = 'same', boundary = 'symm')


# Show result

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image, cmap = 'gray')
plt.subplot(1,2,2)
plt.title("After Convolution")
plt.imshow(convolved, cmap = 'gray')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import convolve2d
from skimage import data, color

# Load grayscale image
image = color.rgb2gray(data.cat())

# Define a simple edge detection Filter

filter = np.array([[-1,-1,-1],
                   [0,0,0],
                   [1,1,1]])
# Apply Convolution

convolved = convolve2d(image, filter, mode = 'same', boundary = 'symm')


# Show result

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image, cmap = 'gray')
plt.subplot(1,2,2)
plt.title("After Convolution")
plt.imshow(convolved, cmap = 'gray')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import convolve2d
from skimage import data, color

# Load grayscale image
image = color.rgb2gray(data.cat())

# Define a simple edge detection Filter

filter = np.array([[-1,0,-1],
                   [0,4,0],
                   [-1,0,-1]])
# Apply Convolution

convolved = convolve2d(image, filter, mode = 'same', boundary = 'symm')


# Show result

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image, cmap = 'gray')
plt.subplot(1,2,2)
plt.title("After Convolution")
plt.imshow(convolved, cmap = 'gray')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import convolve2d
from skimage import data, color

# Load grayscale image
image = color.rgb2gray(data.cat())

# Define a simple edge detection Filter

filter = np.array([[-1,0,-1],
                   [0,5,0],
                   [-1,0,-1]])
# Apply Convolution

convolved = convolve2d(image, filter, mode = 'same', boundary = 'symm')


# Show result

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image, cmap = 'gray')
plt.subplot(1,2,2)
plt.title("After Convolution")
plt.imshow(convolved, cmap = 'gray')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import convolve2d
from skimage import data, color

# Load grayscale image
image = color.rgb2gray(data.coffee())

# Define a simple edge detection Filter

filter = np.array([[-1,0,-1],
                   [0,10,0],
                   [-1,0,-1]])
# Apply Convolution

convolved = convolve2d(image, filter, mode = 'same', boundary = 'symm')


# Show result

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image, cmap = 'gray')
plt.subplot(1,2,2)
plt.title("After Convolution")
plt.imshow(convolved, cmap = 'gray')
plt.show()
