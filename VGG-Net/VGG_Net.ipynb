# %%
data_dir = r"C:\Tutorial\Visuara\Computer vision from Scratch\flowers"

# %%
# !C:\PYTHON_ENV\env_object_detection\Scripts\python.exe -m pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in c:\python_env\env_object_detection\lib\site-packages (1.5.1)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\PYTHON_ENV\env_object_detection\Scripts\python.exe -m pip install --upgrade pip

# %%
# !pip install torchsummary

# !pip install torchinfo
# Out:
# Requirement already satisfied: torchsummary in c:\users\sangr\anaconda3\lib\site-packages (1.5.1)
# WARNING: Ignoring invalid distribution -umpy (c:\users\sangr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\sangr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\sangr\anaconda3\lib\site-packages)
# Requirement already satisfied: torchinfo in c:\users\sangr\anaconda3\lib\site-packages (1.8.0)
# WARNING: Ignoring invalid distribution -umpy (c:\users\sangr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\sangr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\sangr\anaconda3\lib\site-packages)

# %%
import sys
print(sys.executable)
# Out:
# C:\PYTHON_ENV\env_object_detection\Scripts\python.exe

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from torchvision import models

from torchsummary import summary

import wandb
import os

# %%
# =======================
# STEP 0: Initialize wandb
# =======================
wandb.init(project="alexnet-flowers-v2", config={
    "epochs": 10,
    "batch_size": 16,
    "learning_rate": 0.001,
    "architecture": "VGG",
    "pretrained": True,
    "input_size": 128
})

# Shortcut to config values
config = wandb.config
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from C:\Users\sangr\_netrc.
# wandb: Currently logged in as: sangram01 (sangram01-srm-institute-of-science-and-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>C:\Users\sangr\Computer_vision_from_Scratch\wandb\run-20260326_151424-3kzuxiwn</code>
# Syncing run <strong><a href='https://wandb.ai/sangram01-srm-institute-of-science-and-technology/alexnet-flowers-v2/runs/3kzuxiwn' target="_blank">desert-dragon-3</a></strong> to <a href='https://wandb.ai/sangram01-srm-institute-of-science-and-technology/alexnet-flowers-v2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sangram01-srm-institute-of-science-and-technology/alexnet-flowers-v2' target="_blank">https://wandb.ai/sangram01-srm-institute-of-science-and-technology/alexnet-flowers-v2</a>
#  View run at <a href='https://wandb.ai/sangram01-srm-institute-of-science-and-technology/alexnet-flowers-v2/runs/3kzuxiwn' target="_blank">https://wandb.ai/sangram01-srm-institute-of-science-and-technology/alexnet-flowers-v2/runs/3kzuxiwn</a>

# %%
# =======================
# STEP 1: Data Preparation
# =======================

# Transforms for training and validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
}

train_dir = r"C:\Tutorial\Visuara\Computer vision from Scratch\flowers/train"
val_dir = r"C:\Tutorial\Visuara\Computer vision from Scratch\flowers/val"

train_dataset = datasets.ImageFolder(root=train_dir, transform=data_transforms['train'])
val_dataset = datasets.ImageFolder(root=val_dir, transform=data_transforms['val'])

train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config.batch_size)

# %%
# ===========================
# STEP 2: Load Pretrained Model
# ===========================

model = models.vgg16(pretrained=config.pretrained)

# Freeze feature layers
for param in model.features.parameters():
    param.requires_grad = False

# Replace classifier
model.classifier = nn.Sequential(
    nn.Linear(25088, 4096),
    nn.ReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(4096, 4096),
    nn.ReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(4096, 5)  # 5 output classes for flower dataset
)

# Only unfreeze the final classifier layer (index -1)
for param in model.classifier[-1].parameters():
    param.requires_grad = True

# Move model to device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model = model.to(device)

# Watch the model's weights and gradients
wandb.watch(model, log="all", log_freq=10)
# Out:
# C:\PYTHON_ENV\env_object_detection\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\PYTHON_ENV\env_object_detection\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to C:\Users\sangr/.cache\torch\hub\checkpoints\vgg16-397923af.pth
# 100%|███████████████████████████████████████████████████████████████████████████████| 528M/528M [01:22<00:00, 6.73MB/s]

# %%
# ===================
# STEP 3: Loss & Optimizer
# ===================

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, epochs=10):
    for epoch in range(epochs):
        model.train()
        train_correct = 0
        train_total = 0
        running_loss = 0.0

        print(f"\nEpoch {epoch + 1}/{epochs}")
        print("-" * 30)

        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            batch_correct = (preds == labels).sum().item()
            train_correct += batch_correct
            train_total += labels.size(0)

            # Print every 10 batches
            if (i + 1) % 10 == 0:
                batch_acc = batch_correct / labels.size(0)
                print(f"[Batch {i+1}/{len(train_loader)}] Loss: {loss.item():.4f}, Batch Acc: {batch_acc:.4f}")

        train_acc = train_correct / train_total
        wandb.log({"epoch": epoch + 1, "train_loss": running_loss, "train_accuracy": train_acc})
        print(f"Epoch {epoch+1} Summary - Loss: {running_loss:.4f}, Train Accuracy: {train_acc:.4f}")

        # Validation
        model.eval()
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_acc = val_correct / val_total
        wandb.log({"epoch": epoch + 1, "val_accuracy": val_acc})
        print(f"Validation Accuracy: {val_acc:.4f}")

# %%
# ===================
# Train the model
# ===================
train_model(model, criterion, optimizer, train_loader, 
            val_loader, epochs=config.epochs)
# Out:
# Epoch 1/10
# ------------------------------
# [Batch 10/251] Loss: 1.6639, Batch Acc: 0.1250
# [Batch 20/251] Loss: 0.9128, Batch Acc: 0.5625
# [Batch 30/251] Loss: 1.0985, Batch Acc: 0.5625
# [Batch 40/251] Loss: 0.9663, Batch Acc: 0.8125
# [Batch 50/251] Loss: 0.9446, Batch Acc: 0.6250
# [Batch 60/251] Loss: 0.4720, Batch Acc: 0.8125
# [Batch 70/251] Loss: 0.5571, Batch Acc: 0.8125
# [Batch 80/251] Loss: 0.2930, Batch Acc: 0.8750
# [Batch 90/251] Loss: 0.3495, Batch Acc: 0.8125
# [Batch 100/251] Loss: 0.7993, Batch Acc: 0.6875
# [Batch 110/251] Loss: 0.4988, Batch Acc: 0.9375
# [Batch 120/251] Loss: 0.1735, Batch Acc: 0.9375
# [Batch 130/251] Loss: 1.0010, Batch Acc: 0.7500
# [Batch 140/251] Loss: 0.9875, Batch Acc: 0.6250
# [Batch 150/251] Loss: 0.9520, Batch Acc: 0.6875
# [Batch 160/251] Loss: 0.5544, Batch Acc: 0.7500
# [Batch 170/251] Loss: 0.7033, Batch Acc: 0.7500
# [Batch 180/251] Loss: 0.6919, Batch Acc: 0.8125
# [Batch 190/251] Loss: 2.1558, Batch Acc: 0.4375
# [Batch 200/251] Loss: 0.8788, Batch Acc: 0.7500
# [Batch 210/251] Loss: 0.4087, Batch Acc: 0.8750
# [Batch 220/251] Loss: 0.3369, Batch Acc: 0.8750
# [Batch 230/251] Loss: 0.3279, Batch Acc: 0.8750
# [Batch 240/251] Loss: 1.6232, Batch Acc: 0.7500
# [Batch 250/251] Loss: 2.3774, Batch Acc: 0.5625
# Epoch 1 Summary - Loss: 268.9025, Train Accuracy: 0.7098
# Validation Accuracy: 0.8051
#
# Epoch 2/10
# ------------------------------
# [Batch 10/251] Loss: 0.4941, Batch Acc: 0.8125
# [Batch 20/251] Loss: 0.3508, Batch Acc: 0.8125
# [Batch 30/251] Loss: 0.3939, Batch Acc: 0.8125
# [Batch 40/251] Loss: 0.2543, Batch Acc: 0.8125
# [Batch 50/251] Loss: 0.8648, Batch Acc: 0.8750
# [Batch 60/251] Loss: 0.3109, Batch Acc: 0.8750
# [Batch 70/251] Loss: 0.2464, Batch Acc: 0.9375
# [Batch 80/251] Loss: 0.8502, Batch Acc: 0.7500
# [Batch 90/251] Loss: 0.1430, Batch Acc: 0.9375
# [Batch 100/251] Loss: 0.6032, Batch Acc: 0.8750
# [Batch 110/251] Loss: 0.8118, Batch Acc: 0.8750
# [Batch 120/251] Loss: 0.1809, Batch Acc: 0.9375
# [Batch 130/251] Loss: 2.8424, Batch Acc: 0.6875
# [Batch 140/251] Loss: 1.6771, Batch Acc: 0.7500
# [Batch 150/251] Loss: 0.8202, Batch Acc: 0.6875
# [Batch 160/251] Loss: 0.9551, Batch Acc: 0.8750
# [Batch 170/251] Loss: 0.1986, Batch Acc: 0.9375
# [Batch 180/251] Loss: 0.5676, Batch Acc: 0.9375
# [Batch 190/251] Loss: 1.2820, Batch Acc: 0.7500
# [Batch 200/251] Loss: 0.5952, Batch Acc: 0.8125
# [Batch 210/251] Loss: 1.1156, Batch Acc: 0.7500
# [Batch 220/251] Loss: 1.5646, Batch Acc: 0.7500
# [Batch 230/251] Loss: 0.0016, Batch Acc: 1.0000
# [Batch 240/251] Loss: 0.2655, Batch Acc: 0.8750
# [Batch 250/251] Loss: 0.9419, Batch Acc: 0.8750
# Epoch 2 Summary - Loss: 182.2074, Train Accuracy: 0.8306
# Validation Accuracy: 0.8684
#
# Epoch 3/10
# ------------------------------
# [Batch 10/251] Loss: 0.3856, Batch Acc: 0.8750
# [Batch 20/251] Loss: 0.2119, Batch Acc: 0.9375
# [Batch 30/251] Loss: 0.6618, Batch Acc: 0.8125
# [Batch 40/251] Loss: 0.9416, Batch Acc: 0.8750
# [Batch 50/251] Loss: 0.6459, Batch Acc: 0.8125
# [Batch 60/251] Loss: 0.3977, Batch Acc: 0.8750
# [Batch 70/251] Loss: 1.0988, Batch Acc: 0.9375
# [Batch 80/251] Loss: 1.2320, Batch Acc: 0.8750
# [Batch 90/251] Loss: 0.4977, Batch Acc: 0.8750
# [Batch 100/251] Loss: 0.9411, Batch Acc: 0.8750
# [Batch 110/251] Loss: 0.1118, Batch Acc: 0.9375
# [Batch 120/251] Loss: 0.9223, Batch Acc: 0.8125
# [Batch 130/251] Loss: 1.4577, Batch Acc: 0.7500
# [Batch 140/251] Loss: 2.0495, Batch Acc: 0.8125
# [Batch 150/251] Loss: 0.8796, Batch Acc: 0.8125
# [Batch 160/251] Loss: 1.2370, Batch Acc: 0.7500
# [Batch 170/251] Loss: 1.1842, Batch Acc: 0.5625
# [Batch 180/251] Loss: 1.8254, Batch Acc: 0.7500
# [Batch 190/251] Loss: 1.5075, Batch Acc: 0.8750
# [Batch 200/251] Loss: 0.5849, Batch Acc: 0.8750
# [Batch 210/251] Loss: 1.1377, Batch Acc: 0.7500
# [Batch 220/251] Loss: 1.0224, Batch Acc: 0.9375
# [Batch 230/251] Loss: 0.0351, Batch Acc: 1.0000
# [Batch 240/251] Loss: 0.6627, Batch Acc: 0.9375
# [Batch 250/251] Loss: 0.2179, Batch Acc: 0.8750
# Epoch 3 Summary - Loss: 184.4902, Train Accuracy: 0.8603
# Validation Accuracy: 0.8793
#
# Epoch 4/10
# ------------------------------
# [Batch 10/251] Loss: 0.5313, Batch Acc: 0.9375
# [Batch 20/251] Loss: 1.0718, Batch Acc: 0.7500
# [Batch 30/251] Loss: 3.2803, Batch Acc: 0.7500
# [Batch 40/251] Loss: 0.3820, Batch Acc: 0.9375
# [Batch 50/251] Loss: 0.4044, Batch Acc: 0.8125
# [Batch 60/251] Loss: 0.3520, Batch Acc: 0.8125
# [Batch 70/251] Loss: 1.3592, Batch Acc: 0.7500
# [Batch 80/251] Loss: 0.9299, Batch Acc: 0.8125
# [Batch 90/251] Loss: 0.1627, Batch Acc: 0.9375
# [Batch 100/251] Loss: 0.6263, Batch Acc: 0.8750
# [Batch 110/251] Loss: 1.1911, Batch Acc: 0.7500
# [Batch 120/251] Loss: 0.2013, Batch Acc: 0.8750
# [Batch 130/251] Loss: 2.4250, Batch Acc: 0.8750
# [Batch 140/251] Loss: 0.3584, Batch Acc: 0.9375
# [Batch 150/251] Loss: 1.2398, Batch Acc: 0.9375
# [Batch 160/251] Loss: 0.0548, Batch Acc: 1.0000
# [Batch 170/251] Loss: 1.8199, Batch Acc: 0.7500
# [Batch 180/251] Loss: 1.3664, Batch Acc: 0.8125
# [Batch 190/251] Loss: 4.3594, Batch Acc: 0.8750
# [Batch 200/251] Loss: 0.5713, Batch Acc: 0.9375
# [Batch 210/251] Loss: 2.6025, Batch Acc: 0.7500
# [Batch 220/251] Loss: 0.1923, Batch Acc: 0.9375
# [Batch 230/251] Loss: 0.8157, Batch Acc: 0.8125
# [Batch 240/251] Loss: 0.0001, Batch Acc: 1.0000
# [Batch 250/251] Loss: 1.2801, Batch Acc: 0.8750
# Epoch 4 Summary - Loss: 202.1107, Train Accuracy: 0.8825
# Validation Accuracy: 0.8625
#
# Epoch 5/10
# ------------------------------
# [Batch 10/251] Loss: 0.4808, Batch Acc: 0.8750
# [Batch 20/251] Loss: 0.0211, Batch Acc: 1.0000
# [Batch 30/251] Loss: 1.6887, Batch Acc: 0.8125
# [Batch 40/251] Loss: 0.1754, Batch Acc: 0.9375
# [Batch 50/251] Loss: 0.9468, Batch Acc: 0.8125
# [Batch 60/251] Loss: 2.0588, Batch Acc: 0.8750
# [Batch 70/251] Loss: 0.2195, Batch Acc: 0.9375
# [Batch 80/251] Loss: 2.6449, Batch Acc: 0.7500
# [Batch 90/251] Loss: 0.0095, Batch Acc: 1.0000
# [Batch 100/251] Loss: 1.1484, Batch Acc: 0.9375
# [Batch 110/251] Loss: 0.0513, Batch Acc: 1.0000
# [Batch 120/251] Loss: 2.4128, Batch Acc: 0.8750
# [Batch 130/251] Loss: 0.4099, Batch Acc: 0.8750
# [Batch 140/251] Loss: 0.4407, Batch Acc: 0.8750
# [Batch 150/251] Loss: 1.9186, Batch Acc: 0.8750
# [Batch 160/251] Loss: 0.0005, Batch Acc: 1.0000
# [Batch 170/251] Loss: 0.2000, Batch Acc: 0.9375
# [Batch 180/251] Loss: 1.5229, Batch Acc: 0.8750
# [Batch 190/251] Loss: 2.9614, Batch Acc: 0.7500
# [Batch 200/251] Loss: 0.0008, Batch Acc: 1.0000
# [Batch 210/251] Loss: 3.3956, Batch Acc: 0.7500
# [Batch 220/251] Loss: 0.7785, Batch Acc: 0.8750
# [Batch 230/251] Loss: 2.4476, Batch Acc: 0.7500
# [Batch 240/251] Loss: 2.7971, Batch Acc: 0.7500
# [Batch 250/251] Loss: 3.0455, Batch Acc: 0.7500
# Epoch 5 Summary - Loss: 319.6139, Train Accuracy: 0.8787
# Validation Accuracy: 0.8556
#
# Epoch 6/10
# ------------------------------
# [Batch 10/251] Loss: 1.8025, Batch Acc: 0.7500
# [Batch 20/251] Loss: 1.3573, Batch Acc: 0.8125
# [Batch 30/251] Loss: 1.1326, Batch Acc: 0.9375
# [Batch 40/251] Loss: 0.0108, Batch Acc: 1.0000
# [Batch 50/251] Loss: 4.7314, Batch Acc: 0.6875
# [Batch 60/251] Loss: 1.6246, Batch Acc: 0.7500
# [Batch 70/251] Loss: 0.1148, Batch Acc: 0.9375
# [Batch 80/251] Loss: 0.5246, Batch Acc: 0.9375
# [Batch 90/251] Loss: 0.0302, Batch Acc: 1.0000
# [Batch 100/251] Loss: 2.1602, Batch Acc: 0.8750
# [Batch 110/251] Loss: 0.1472, Batch Acc: 0.9375
# [Batch 120/251] Loss: 1.8953, Batch Acc: 0.8125
# [Batch 130/251] Loss: 0.6540, Batch Acc: 0.8750
# [Batch 140/251] Loss: 1.0794, Batch Acc: 0.8750
# [Batch 150/251] Loss: 4.6319, Batch Acc: 0.8750
# [Batch 160/251] Loss: 0.3562, Batch Acc: 0.9375
# [Batch 170/251] Loss: 0.0507, Batch Acc: 1.0000
# [Batch 180/251] Loss: 0.5488, Batch Acc: 0.9375
# [Batch 190/251] Loss: 0.4170, Batch Acc: 0.9375
# [Batch 200/251] Loss: 0.0640, Batch Acc: 0.9375
# [Batch 210/251] Loss: 0.2342, Batch Acc: 0.9375
# [Batch 220/251] Loss: 1.2585, Batch Acc: 0.8125
# [Batch 230/251] Loss: 0.0338, Batch Acc: 1.0000
# [Batch 240/251] Loss: 3.1820, Batch Acc: 0.7500
# [Batch 250/251] Loss: 0.0028, Batch Acc: 1.0000
# Epoch 6 Summary - Loss: 256.2980, Train Accuracy: 0.9057
# Validation Accuracy: 0.8744
#
# Epoch 7/10
# ------------------------------
# [Batch 10/251] Loss: 0.1655, Batch Acc: 0.8750
# [Batch 20/251] Loss: 0.0006, Batch Acc: 1.0000
# [Batch 30/251] Loss: 2.9140, Batch Acc: 0.8750
# [Batch 40/251] Loss: 0.0467, Batch Acc: 0.9375
# [Batch 50/251] Loss: 1.0679, Batch Acc: 0.8125
# [Batch 60/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 70/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 80/251] Loss: 0.3117, Batch Acc: 0.9375
# [Batch 90/251] Loss: 0.0144, Batch Acc: 1.0000
# [Batch 100/251] Loss: 3.6012, Batch Acc: 0.8125
# [Batch 110/251] Loss: 0.9937, Batch Acc: 0.8750
# [Batch 120/251] Loss: 0.2307, Batch Acc: 0.9375
# [Batch 130/251] Loss: 0.8759, Batch Acc: 0.8125
# [Batch 140/251] Loss: 0.8510, Batch Acc: 0.9375
# [Batch 150/251] Loss: 0.0043, Batch Acc: 1.0000
# [Batch 160/251] Loss: 0.2160, Batch Acc: 0.8750
# [Batch 170/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 180/251] Loss: 0.8154, Batch Acc: 0.9375
# [Batch 190/251] Loss: 0.0351, Batch Acc: 1.0000
# [Batch 200/251] Loss: 1.2225, Batch Acc: 0.8125
# [Batch 210/251] Loss: 2.6064, Batch Acc: 0.9375
# [Batch 220/251] Loss: 4.2174, Batch Acc: 0.7500
# [Batch 230/251] Loss: 1.1558, Batch Acc: 0.8750
# [Batch 240/251] Loss: 1.1865, Batch Acc: 0.8750
# [Batch 250/251] Loss: 0.5150, Batch Acc: 0.9375
# Epoch 7 Summary - Loss: 247.2436, Train Accuracy: 0.9162
# Validation Accuracy: 0.8991
#
# Epoch 8/10
# ------------------------------
# [Batch 10/251] Loss: 0.0071, Batch Acc: 1.0000
# [Batch 20/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 30/251] Loss: 3.0774, Batch Acc: 0.8750
# [Batch 40/251] Loss: 1.2866, Batch Acc: 0.8750
# [Batch 50/251] Loss: 0.0261, Batch Acc: 1.0000
# [Batch 60/251] Loss: 0.0002, Batch Acc: 1.0000
# [Batch 70/251] Loss: 4.2011, Batch Acc: 0.9375
# [Batch 80/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 90/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 100/251] Loss: 0.6133, Batch Acc: 0.8750
# [Batch 110/251] Loss: 1.8896, Batch Acc: 0.8125
# [Batch 120/251] Loss: 3.4041, Batch Acc: 0.6875
# [Batch 130/251] Loss: 2.8840, Batch Acc: 0.8125
# [Batch 140/251] Loss: 2.1647, Batch Acc: 0.8125
# [Batch 150/251] Loss: 0.2992, Batch Acc: 0.9375
# [Batch 160/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 170/251] Loss: 1.1705, Batch Acc: 0.8750
# [Batch 180/251] Loss: 1.1886, Batch Acc: 0.8750
# [Batch 190/251] Loss: 0.9479, Batch Acc: 0.9375
# [Batch 200/251] Loss: 8.4777, Batch Acc: 0.8125
# [Batch 210/251] Loss: 0.0153, Batch Acc: 1.0000
# [Batch 220/251] Loss: 3.7536, Batch Acc: 0.8125
# [Batch 230/251] Loss: 0.4169, Batch Acc: 0.9375
# [Batch 240/251] Loss: 0.0257, Batch Acc: 1.0000
# [Batch 250/251] Loss: 4.7080, Batch Acc: 0.8125
# Epoch 8 Summary - Loss: 277.0542, Train Accuracy: 0.9237
# Validation Accuracy: 0.9041
#
# Epoch 9/10
# ------------------------------
# [Batch 10/251] Loss: 0.0036, Batch Acc: 1.0000
# [Batch 20/251] Loss: 3.0737, Batch Acc: 0.8750
# [Batch 30/251] Loss: 1.7100, Batch Acc: 0.8750
# [Batch 40/251] Loss: 0.0037, Batch Acc: 1.0000
# [Batch 50/251] Loss: 0.0012, Batch Acc: 1.0000
# [Batch 60/251] Loss: 0.0005, Batch Acc: 1.0000
# [Batch 70/251] Loss: 0.0012, Batch Acc: 1.0000
# [Batch 80/251] Loss: 0.0004, Batch Acc: 1.0000
# [Batch 90/251] Loss: 0.7959, Batch Acc: 0.8750
# [Batch 100/251] Loss: 1.5026, Batch Acc: 0.8125
# [Batch 110/251] Loss: 1.5125, Batch Acc: 0.9375
# [Batch 120/251] Loss: 0.2294, Batch Acc: 0.9375
# [Batch 130/251] Loss: 0.0002, Batch Acc: 1.0000
# [Batch 140/251] Loss: 3.1571, Batch Acc: 0.9375
# [Batch 150/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 160/251] Loss: 1.4834, Batch Acc: 0.8750
# [Batch 170/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 180/251] Loss: 0.0002, Batch Acc: 1.0000
# [Batch 190/251] Loss: 0.0009, Batch Acc: 1.0000
# [Batch 200/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 210/251] Loss: 0.7932, Batch Acc: 0.9375
# [Batch 220/251] Loss: 0.8080, Batch Acc: 0.9375
# [Batch 230/251] Loss: 0.3679, Batch Acc: 0.8750
# [Batch 240/251] Loss: 0.1568, Batch Acc: 0.9375
# [Batch 250/251] Loss: 0.5368, Batch Acc: 0.8750
# Epoch 9 Summary - Loss: 289.1751, Train Accuracy: 0.9284
# Validation Accuracy: 0.9120
#
# Epoch 10/10
# ------------------------------
# [Batch 10/251] Loss: 0.1721, Batch Acc: 0.9375
# [Batch 20/251] Loss: 1.1826, Batch Acc: 0.8750
# [Batch 30/251] Loss: 0.0009, Batch Acc: 1.0000
# [Batch 40/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 50/251] Loss: 0.4764, Batch Acc: 0.9375
# [Batch 60/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 70/251] Loss: 1.5318, Batch Acc: 0.8750
# [Batch 80/251] Loss: 1.0176, Batch Acc: 0.8750
# [Batch 90/251] Loss: 0.0225, Batch Acc: 1.0000
# [Batch 100/251] Loss: 0.0663, Batch Acc: 0.9375
# [Batch 110/251] Loss: 0.8089, Batch Acc: 0.9375
# [Batch 120/251] Loss: 0.0019, Batch Acc: 1.0000
# [Batch 130/251] Loss: 2.1454, Batch Acc: 0.7500
# [Batch 140/251] Loss: 1.0171, Batch Acc: 0.8750
# [Batch 150/251] Loss: 0.2978, Batch Acc: 0.9375
# [Batch 160/251] Loss: 0.0051, Batch Acc: 1.0000
# [Batch 170/251] Loss: 0.0001, Batch Acc: 1.0000
# [Batch 180/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 190/251] Loss: 1.6948, Batch Acc: 0.8750
# [Batch 200/251] Loss: 0.1522, Batch Acc: 0.9375
# [Batch 210/251] Loss: 4.7779, Batch Acc: 0.8750
# [Batch 220/251] Loss: 0.0000, Batch Acc: 1.0000
# [Batch 230/251] Loss: 0.6454, Batch Acc: 0.9375
# [Batch 240/251] Loss: 0.9938, Batch Acc: 0.9375
# [Batch 250/251] Loss: 1.0802, Batch Acc: 0.8750
# Epoch 10 Summary - Loss: 246.6871, Train Accuracy: 0.9394
# Validation Accuracy: 0.9050
